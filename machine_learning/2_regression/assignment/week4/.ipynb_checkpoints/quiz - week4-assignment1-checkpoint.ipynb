# %% [markdown]
# # Observing effects of L2 penalty in polynomial regression

# %% [markdown]
# <img src="images/pic01.png">
# <img src="images/pic02.png">
# <img src="images/pic03.png">
# <img src="images/pic04.png">
# *Screenshot taken from [Coursera](https://www.coursera.org/learn/ml-regression/exam/A0as6/observing-effects-of-l2-penalty-in-polynomial-regression)*
#
# <!--TEASER_END-->
